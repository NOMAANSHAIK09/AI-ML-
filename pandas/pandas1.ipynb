# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as np

# %%
#data frame with dict..
info = {
    "name":["rahul","nomaan","shradha"],
    "cgpa":[8.5,5.6,9.8]
}
df = pd.DataFrame(info)

# %%
print(df)
# Out:
#       name  cgpa
# 0    rahul   8.5
# 1   nomaan   5.6
# 2  shradha   9.8

# %%
df
# Out:
#       name  cgpa
# 0    rahul   8.5
# 1   nomaan   5.6
# 2  shradha   9.8

# %%
#seies
s = pd.Series([23,45,67], index=["adnan","eve","bob"])
print(s)
print(s[0])
# Out:
# adnan    23
# eve      45
# bob      67
# dtype: int64
# 23
# C:\Users\Nomaa\AppData\Local\Temp\ipykernel_18564\759968742.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s[0])

# %%
# df with list
df =pd.DataFrame([["adnan",22],["bob",21]],columns=["name","age"])
print(df)
# Out:
#     name  age
# 0  adnan   22
# 1    bob   21

# %%
#df with numpy
nparr=([[1,2,3],[4,5,6]])
df=pd.DataFrame(nparr,columns=["A","b","C"])
print(df)
# Out:
#    A  b  C
# 0  1  2  3
# 1  4  5  6
