# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
page_count = 1

while True:
    URL=f"https://quotes.toscrape.com/page/{page_count}/"
    res = requests.get(URL)
    
    soup=BeautifulSoup(res.text,"lxml")
    quotes=soup.select("div.quote")
    
    if not quotes:
        print("no valid page left...")
        break
        
    with open(f"scraped_data/quotes_data{page_count}.html","w", encoding="utf-8") as f:
        f.write(res.text)
        print(f"download data from page {page_count} ")
    page_count=page_count+1

# %%
with open("scraped_data/quotes_data1.html","r", encoding="utf-8") as f:
      html_content=f.read()

soup = BeautifulSoup(html_content,"lxml")

# %%
all_quotes = soup.select("div.quote")
life_quotes = []

for q in all_quotes:
    all_tags = []

    for tag in q.select(".tags .tag"):
        all_tags.append(tag.get_text())

    if "life" in all_tags:
        text = q.select_one("span.text").get_text()
        author = q.select_one("small.author").get_text()
        life_quotes.append([text, author])

print(life_quotes)

# %%
file_count = 1
dd=[]
while True:
    try:
        with open(f"scraped_data/quotes_data{file_count}.html","r", encoding="utf-8") as f:
              html_content=f.read()
        
        soup = BeautifulSoup(html_content,"lxml")
        all_quotes = soup.select("div.quote")
        life_quotes = []
        
        for q in all_quotes:
            all_tags = []
        
            for tag in q.select(".tags .tag"):
                all_tags.append(tag.get_text())
        
            if "life" in all_tags:
                text = q.select_one("span.text").get_text()
                author = q.select_one("small.author").get_text()
                life_quotes.append([text, author])
                dd.append([text, author])
        print(life_quotes)
        
        file_count=file_count+1
    except FileNotFoundError:

        print("No more files found.")
        break

# %%
pp=pd.DataFrame(dd,columns=["quote","auther"])
df=pp.copy()
df
df.to_csv("cleandata/
