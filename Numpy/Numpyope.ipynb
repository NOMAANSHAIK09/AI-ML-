# %%
import numpy as np

lst=np.array([1,2,3])
print(lst,type(lst))
# Out:
# [1 2 3] <class 'numpy.ndarray'>

# %%
import time
size = 1_000_000
pylst = range(size)
start=time.time()
sq_lst = [x**2 for x in pylst]
end=time.time()
print(f"python list timrvv={end-start}second")

nparr=np.array(pylst)
start1=time.time()
sq_arr=nparr ** 2
end1=time.time()
print(f"numpy arrya time = {end1-start1}")
# Out:
# python list timrvv=0.2763395309448242second
# numpy arrya time = 0.00685572624206543

# %%
import sys
print(f"pytho lst size={sys.getsizeof(pylst) * len(pylst)}bytes")
print(f"numppy arr size = {nparr.nbytes} bytes")
# Out:
# pytho lst size=48000000bytes
# numppy arr size = 4000000 bytes

# %%
arrope=np.array([1,2,3,4,5,6])
print(np.sum(arrope))
print(np.prod(arrope))
print(np.min(arrope))
print(np.max(arrope))
print(np.argmin(arrope))
print(np.argmax(arrope))
print(np.mean(arrope))
print(np.std(arrope))
print(np.median(arrope))
# Out:
# 21
# 720
# 1
# 6
# 0
# 5
# 3.5
# 1.707825127659933
# 3.5
