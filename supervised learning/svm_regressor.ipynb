# %%
from sklearn.svm import SVR
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn import datasets

# %%
df=datasets.load_diabetes(as_frame=True).frame

# %%
x=df.drop("target",axis=1)
y=df["target"]

# %%
x_train,x_test,y_train,y_test=train_test_split(
    x,y,test_size=0.3,random_state=42)

# %%
y_scaler=StandardScaler()
y_train_scaled = y_scaler.fit_transform(y_train.values.reshape(-1,1)).ravel()
y_test_scaled = y_scaler.transform(y_test.values.reshape(-1,1)).ravel()

# %%
model=SVR()

model.fit(x_train,y_train_scaled)
# Out:
# SVR()

# %%
y_pred_scaled = model.predict(x_test)

# %%
print("r2:",r2_score(y_test_scaled,y_pred_scaled)*100)
# Out:
# r2: 48.84444315165189

# %%
model=SVR(kernel="linear")

model.fit(x_train,y_train_scaled)
y_pred_scaled = model.predict(x_test)
print("r2:",r2_score(y_test_scaled,y_pred_scaled)*100)
# Out:
# r2: 44.33761323833776

# %%
model=SVR(kernel="poly")

model.fit(x_train,y_train_scaled)
y_pred_scaled = model.predict(x_test)
print("r2:",r2_score(y_test_scaled,y_pred_scaled)*100)
# Out:
# r2: 24.203771038107757

# %%
model=SVR(kernel="sigmoid")

model.fit(x_train,y_train_scaled)
y_pred_scaled = model.predict(x_test)
print("r2:",r2_score(y_test_scaled,y_pred_scaled)*100)
# Out:
# r2: -1531.6808189576823

# %% [markdown]
# # hyperparameter

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    "C":[1,2,5,10,50,100],
    "kernel":["rbf","linear"],
    "epsilon":[0.01,0.1,0.2,0.3,0.5]
}

# %%
svr = SVR()

grid_search=GridSearchCV(svr, param_grid, scoring="r2",cv=5)
grid_search.fit(x_train, y_train_scaled)
# Out:
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [1, 2, 5, 10, 50, 100],
#                          'epsilon': [0.01, 0.1, 0.2, 0.3, 0.5],
#                          'kernel': ['rbf', 'linear']},
#              scoring='r2')

# %%
print("best parameter -",grid_search.best_params_)
# Out:
# best parameter - {'C': 10, 'epsilon': 0.1, 'kernel': 'linear'}

# %%
best_model = SVR(C= 10, epsilon= 0.1, kernel= 'linear')
best_model.fit(x_train,y_train_scaled)

y_test_pred_scaled = best_model.predict(x_test)
y_train_pred_scaled = best_model.predict(x_train)

print("test r2:",r2_score(y_test_scaled,y_test_pred_scaled)*100)
print("train r2:",r2_score(y_train_scaled,y_train_pred_scaled)*100)
# Out:
# test r2: 47.444183250401096
# train r2: 51.51066486918876
